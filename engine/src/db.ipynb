# %% [markdown]
# This is code wrritten in python to post data in to database.
# database: mongoDB

# %%
#fileName : db.py
#author : Aishwarya Pagalla
# last modified : 10/24/2018
import pprint
from sys_met import *
from pymongo import MongoClient
#connecting to MongoDB Server
client = MongoClient()
client = MongoClient('localhost', 27017)
#Creating DataBase
db = client.test_database
db = client["metdb0"]
#Collections
collection = db.test_collection
collection = db['metcollector']
#Documents to post in db 
doc1 = sys_met.met
doc2 = sys_met.sett
doc3 = sys_met.inf		
#creating collections in db
postmet = db.postmet
postsett = db.postsett
postinf = db.postinf
#inserting Documents as collections in db and getting id
post_id = postmet.insert_one(doc1).inserted_id
post_id = postsett.insert_one(doc2).inserted_id
post_id = postinf.insert_one(doc3).inserted_id
print(post_id)
db.collection_names(include_system_collections=False)
#query to print collections
pprint.pprint(postmet.find_one())
pprint.pprint(postsett.find_one())
pprint.pprint(postinf.find_one())
# Out:
# 5c007c2fe21a732df8d2d757
# {'ProcessExePath': [None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     'C:\\WINDOWS\\system32\\Intel\\DPTF\\dptf_helper.exe',
#                     'c:\\windows\\system32\\sihost.exe',
#                     'c:\\windows\\system32\\svchost.exe',
#                     None,
#                     None,
#                     None,
#                     None,
#                     'c:\\windows\\system32\\svchost.exe',
#                     None,
#                     'c:\\windows\\system32\\taskhostw.exe',
#                     None,
#                     'C:\\WINDOWS\\Explorer.EXE',
#                     'c:\\windows\\system32\\svchost.exe',
#                     None,
#                     None,
#                     None,
#                     'C:\\WINDOWS\\System32\\DriverStore\\FileRepository\\ki125183.inf_amd64_cb49708b33bad074\\igfxEM.exe',
#                     'C:\\WINDOWS\\system32\\DllHost.exe',
#                     'C:\\Windows\\SystemApps\\ShellExperienceHost_cw5n1h2txyewy\\ShellExperienceHost.exe',
#                     None,
#                     'C:\\Windows\\SystemApps\\Microsoft.Windows.Cortana_cw5n1h2txyewy\\SearchUI.exe',
#                     'C:\\Windows\\System32\\RuntimeBroker.exe',
#                     'C:\\Windows\\System32\\RuntimeBroker.exe',
#                     None,
#                     'C:\\Windows\\System32\\RuntimeBroker.exe',
#                     'C:\\WINDOWS\\system32\\ApplicationFrameHost.exe',
#                     'C:\\Windows\\SystemApps\\Microsoft.Windows.Cortana_cw5n1h2txyewy\\RemindersServer.exe',
#                     'C:\\Program '
#                     'Files\\WindowsApps\\Microsoft.SkypeApp_14.34.81.0_x64__kzf8qxf38zg5c\\SkypeApp.exe',
#                     'C:\\Program '
#                     'Files\\WindowsApps\\Microsoft.ZuneVideo_10.18082.13811.0_x64__8wekyb3d8bbwe\\Video.UI.exe',
#                     'C:\\Windows\\SystemApps\\Microsoft.MicrosoftEdge_8wekyb3d8bbwe\\MicrosoftEdge.exe',
#                     None,
#                     None,
#                     'C:\\WINDOWS\\system32\\browser_broker.exe',
#                     'C:\\WINDOWS\\system32\\DllHost.exe',
#                     None,
#                     'C:\\Windows\\System32\\RuntimeBroker.exe',
#                     'C:\\Program '
#                     'Files\\WindowsApps\\Microsoft.SkypeApp_14.34.81.0_x64__kzf8qxf38zg5c\\SkypeBackgroundHost.exe',
#                     'C:\\Windows\\System32\\RuntimeBroker.exe',
#                     None,
#                     'C:\\Windows\\SystemApps\\Microsoft.MicrosoftEdge_8wekyb3d8bbwe\\MicrosoftEdgeCP.exe',
#                     'C:\\Windows\\SystemApps\\Microsoft.MicrosoftEdge_8wekyb3d8bbwe\\MicrosoftEdgeCP.exe',
#                     'C:\\WINDOWS\\system32\\SettingSyncHost.exe',
#                     'C:\\Program Files\\Windows Defender\\MSASCuiL.exe',
#                     'C:\\Program Files\\Realtek\\Audio\\HDA\\RtkNGUI64.exe',
#                     'C:\\Program Files\\Realtek\\Audio\\HDA\\RAVBg64.exe',
#                     'C:\\Program Files\\TrueColor\\TrueColorUI.exe',
#                     'C:\\Program Files\\Waves\\MaxxAudio\\WavesSvc64.exe',
#                     'C:\\Users\\aishw\\AppData\\Local\\WebEx\\WebEx\\Applications\\ptoneclk.exe',
#                     'C:\\Program Files (x86)\\Cisco\\Cisco AnyConnect Secure '
#                     'Mobility Client\\vpnui.exe',
#                     'C:\\Program Files (x86)\\Common Files\\Java\\Java '
#                     'Update\\jusched.exe',
#                     'C:\\Program '
#                     'Files\\WindowsApps\\Microsoft.XboxGamingOverlay_1.16.1012.0_x64__8wekyb3d8bbwe\\GameBar.exe',
#                     'C:\\Program Files (x86)\\Razer\\RzWizard\\RzWizard.exe',
#                     'C:\\Users\\aishw\\AppData\\Local\\Webex\\Webex\\Applications\\ptSrv.exe',
#                     None,
#                     'C:\\Users\\aishw\\AppData\\Local\\Webex\\Webex\\Applications\\ptOIEx.exe',
#                     None,
#                     None,
#                     'C:\\Windows\\System32\\RuntimeBroker.exe',
#                     None,
#                     None,
#                     None,
#                     'C:\\Program Files\\Intel\\Intel(R) Rapid Storage '
#                     'Technology\\IAStorIcon.exe',
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     'C:\\Program Files (x86)\\RelevantKnowledge\\rlvknlg.exe',
#                     None,
#                     'C:\\WINDOWS\\system32\\wbem\\unsecapp.exe',
#                     'C:\\WINDOWS\\SysWOW64\\cmd.exe',
#                     'C:\\WINDOWS\\SysWOW64\\cmd.exe',
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     None,
#                     'C:\\Program '
#                     'Files\\WindowsApps\\Microsoft.Windows.Photos_2018.18091.17210.0_x64__8wekyb3d8bbwe\\Microsoft.Photos.exe',
#                     'C:\\Windows\\System32\\RuntimeBroker.exe',
#                     'C:\\Program Files (x86)\\Notepad++\\notepad++.exe',
#                     None,
#                     'C:\\Program Files '
#                     '(x86)\\Google\\Chrome\\Application\\chrome.exe',
#                     'C:\\Program Files '
#                     '(x86)\\Google\\Chrome\\Application\\chrome.exe',
#                     'C:\\Program Files '
#                     '(x86)\\Google\\Chrome\\Application\\chrome.exe',
#                     'C:\\Program Files '
#                     '(x86)\\Google\\Chrome\\Application\\chrome.exe',
#                     'C:\\Program Files '
#                     '(x86)\\Google\\Chrome\\Application\\chrome.exe',
#                     'C:\\Program Files '
#                     '(x86)\\Google\\Chrome\\Application\\chrome.exe',
#                     'C:\\Program Files '
#                     '(x86)\\Google\\Chrome\\Application\\chrome.exe',
#                     'C:\\Program Files '
#                     '(x86)\\Google\\Chrome\\Application\\chrome.exe',
#                     'C:\\Program Files\\MongoDB\\Server\\4.0\\bin\\mongo.exe',
#                     'C:\\WINDOWS\\system32\\conhost.exe',
#                     'C:\\Program Files '
#                     '(x86)\\Google\\Chrome\\Application\\chrome.exe',
#                     'C:\\Program Files '
#                     '(x86)\\Google\\Chrome\\Application\\chrome.exe',
#                     None,
#                     None,
#                     None,
#                     'C:\\Windows\\System32\\smartscreen.exe',
#                     'C:\\WINDOWS\\system32\\cmd.exe',
#                     'C:\\WINDOWS\\system32\\conhost.exe',
#                     'C:\\Users\\aishw\\Anaconda3\\python.exe'],
#  'ProcessID': [0,
#                4,
#                96,
#                404,
#                592,
#                684,
#                712,
#                756,
#                840,
#                864,
#                980,
#                988,
#                528,
#                512,
#                616,
#                1028,
#                1096,
#                1148,
#                1232,
#                1244,
#                1332,
#                1384,
#                1424,
#                1472,
#                1528,
#                1636,
#                1756,
#                1764,
#                1772,
#                1780,
#                1844,
#                1916,
#                1940,
#                1988,
#                2008,
#                1120,
#                2092,
#                2100,
#                2176,
#                2224,
#                2232,
#                2264,
#                2296,
#                2408,
#                2604,
#                2700,
#                2756,
#                2864,
#                2896,
#                2904,
#                2912,
#                2932,
#                2380,
#                3096,
#                3120,
#                3236,
#                3356,
#                3368,
#                3464,
#                3536,
#                3680,
#                3724,
#                3732,
#                3964,
#                3972,
#                3980,
#                3988,
#                4012,
#                4044,
#                4052,
#                4060,
#                4080,
#                2840,
#                3092,
#                2192,
#                3416,
#                3608,
#                4148,
#                4188,
#                4228,
#                4236,
#                4252,
#                4296,
#                4308,
#                4328,
#                4488,
#                4516,
#                4528,
#                4652,
#                4760,
#                4768,
#                5020,
#                5220,
#                5500,
#                5652,
#                5956,
#                6076,
#                5844,
#                4708,
#                4860,
#                732,
#                6220,
#                6276,
#                6292,
#                6368,
#                6808,
#                6948,
#                7060,
#                7248,
#                7784,
#                7916,
#                7980,
#                2584,
#                4368,
#                8160,
#                8384,
#                8440,
#                8724,
#                8748,
#                9068,
#                8208,
#                3592,
#                3488,
#                6892,
#                2440,
#                3016,
#                4068,
#                9632,
#                9660,
#                5576,
#                7868,
#                7840,
#                10380,
#                10648,
#                10676,
#                10784,
#                10352,
#                10336,
#                9792,
#                5880,
#                9712,
#                4612,
#                5432,
#                6928,
#                11308,
#                11964,
#                12060,
#                12120,
#                12140,
#                2628,
#                9384,
#                12368,
#                6608,
#                10924,
#                12744,
#                10560,
#                4416,
#                13028,
#                13016,
#                12556,
#                13276,
#                9748,
#                7824,
#                9596,
#                2872,
#                8900,
#                10576,
#                3372,
#                12384,
#                13724,
#                9940,
#                11828,
#                14220,
#                14232,
#                14224,
#                12540,
#                12532,
#                12760,
#                2080,
#                13380,
#                9848,
#                14116,
#                920,
#                11608,
#                13652,
#                11804,
#                3132,
#                5340,
#                4088,
#                116,
#                10996,
#                12676,
#                2784,
#                10688,
#                7460,
#                12356,
#                10780,
#                11860,
#                9820,
#                1368,
#                7536,
#                11468,
#                11416],
#  'ProcessName': ['System Idle Process',
#                  'System',
#                  'Registry',
#                  'smss.exe',
#                  'csrss.exe',
#                  'csrss.exe',
#                  'wininit.exe',
#                  'winlogon.exe',
#                  'services.exe',
#                  'lsass.exe',
#                  'svchost.exe',
#                  'WUDFHost.exe',
#                  'svchost.exe',
#                  'fontdrvhost.exe',
#                  'fontdrvhost.exe',
#                  'WUDFHost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'dwm.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'Memory Compression',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'igfxCUIService.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'RtkAudioService64.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'vpnagent.exe',
#                  'svchost.exe',
#                  'RAVBg64.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'wlanext.exe',
#                  'conhost.exe',
#                  'svchost.exe',
#                  'spoolsv.exe',
#                  'svchost.exe',
#                  'audiodg.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'IntelCpHDCPSvc.exe',
#                  'svchost.exe',
#                  'esif_uf.exe',
#                  'svchost.exe',
#                  'ibtsiva.exe',
#                  'EvtEng.exe',
#                  'mongod.exe',
#                  'Recorder.exe',
#                  'RegSrvc.exe',
#                  'RzWizardService.exe',
#                  'svchost.exe',
#                  'SecurityHealthService.exe',
#                  'SmartByteNetworkService.exe',
#                  'TeamViewer_Service.exe',
#                  'TrueColorALS.exe',
#                  'svchost.exe',
#                  'WavesSysSvc64.exe',
#                  'MsMpEng.exe',
#                  'svchost.exe',
#                  'ZeroConfigService.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'IntelCpHeciSvc.exe',
#                  'igfxext.exe',
#                  'svchost.exe',
#                  'RNDBWMService.exe',
#                  'unsecapp.exe',
#                  'WmiPrvSE.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'dptf_helper.exe',
#                  'sihost.exe',
#                  'svchost.exe',
#                  'WmiPrvSE.exe',
#                  'PresentationFontCache.exe',
#                  'RNDBWM.exe',
#                  'conhost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'taskhostw.exe',
#                  'svchost.exe',
#                  'explorer.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'NisSrv.exe',
#                  'igfxEM.exe',
#                  'dllhost.exe',
#                  'ShellExperienceHost.exe',
#                  'SearchIndexer.exe',
#                  'SearchUI.exe',
#                  'RuntimeBroker.exe',
#                  'RuntimeBroker.exe',
#                  'svchost.exe',
#                  'RuntimeBroker.exe',
#                  'ApplicationFrameHost.exe',
#                  'RemindersServer.exe',
#                  'SkypeApp.exe',
#                  'Video.UI.exe',
#                  'MicrosoftEdge.exe',
#                  'ctfmon.exe',
#                  'TabTip.exe',
#                  'browser_broker.exe',
#                  'dllhost.exe',
#                  'svchost.exe',
#                  'RuntimeBroker.exe',
#                  'SkypeBackgroundHost.exe',
#                  'RuntimeBroker.exe',
#                  'svchost.exe',
#                  'MicrosoftEdgeCP.exe',
#                  'MicrosoftEdgeCP.exe',
#                  'SettingSyncHost.exe',
#                  'MSASCuiL.exe',
#                  'RtkNGUI64.exe',
#                  'RAVBg64.exe',
#                  'TrueColorUI.exe',
#                  'WavesSvc64.exe',
#                  'ptoneclk.exe',
#                  'vpnui.exe',
#                  'jusched.exe',
#                  'GameBar.exe',
#                  'RzWizard.exe',
#                  'ptsrv.exe',
#                  'WmiPrvSE.exe',
#                  'ptOIEx.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'RuntimeBroker.exe',
#                  'DDVRulesProcessor.exe',
#                  'GoogleCrashHandler.exe',
#                  'GoogleCrashHandler64.exe',
#                  'IAStorIcon.exe',
#                  'DSAPI.exe',
#                  'svchost.exe',
#                  'pcdrwi.exe',
#                  'conhost.exe',
#                  'svchost.exe',
#                  'svchost.exe',
#                  'rlservice.exe',
#                  'rlvknlg.exe',
#                  'IAStorDataMgrSvc.exe',
#                  'unsecapp.exe',
#                  'cmd.exe',
#                  'cmd.exe',
#                  'sedsvc.exe',
#                  'rlvknlg64.exe',
#                  'rlvknlg32.exe',
#                  'SgrmBroker.exe',
#                  'SupportAssistAgent.exe',
#                  'DDVDataCollector.exe',
#                  'DDVCollectorSvcApi.exe',
#                  'WmiPrvSE.exe',
#                  'SmartByteTelemetry.exe',
#                  'Microsoft.Photos.exe',
#                  'RuntimeBroker.exe',
#                  'notepad++.exe',
#                  'svchost.exe',
#                  'chrome.exe',
#                  'chrome.exe',
#                  'chrome.exe',
#                  'chrome.exe',
#                  'chrome.exe',
#                  'chrome.exe',
#                  'chrome.exe',
#                  'chrome.exe',
#                  'mongo.exe',
#                  'conhost.exe',
#                  'chrome.exe',
#                  'chrome.exe',
#                  'svchost.exe',
#                  'SearchProtocolHost.exe',
#                  'SearchFilterHost.exe',
#                  'smartscreen.exe',
#                  'cmd.exe',
#                  'conhost.exe',
#                  'python.exe'],
#  'ProcessStatus': [None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None,
#                    None],
#  '_id': ObjectId('5c003366e21a732c989a8bc4')}
# {'MemoryUsage': [8453500928, 3796135936, 55.1, 4657364992, 3796135936],
#  'ProcessorUsage': 40.2,
#  '_id': ObjectId('5c003366e21a732c989a8bc5')}
# {'GPUInfo': 'Intel(R) HD Graphics 620',
#  'OSName': 'Microsoft Windows 10 '
#            'Home|C:\\WINDOWS|\\Device\\Harddisk0\\Partition3',
#  'OSVersion': '10.0.17134',
#  'ProcessInfo': 'Intel(R) Core(TM) i5-7200U CPU @ 2.50GHz',
#  'SystemRam': 7.872936248779297,
#  '_id': ObjectId('5c003366e21a732c989a8bc6')}
# C:\Users\aishw\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: DeprecationWarning: collection_names is deprecated. Use list_collection_names instead.
